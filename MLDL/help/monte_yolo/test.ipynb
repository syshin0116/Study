# %%
from ultralytics import YOLO
import cv2
import numpy as np

# YOLOv8 모델 로드
model = YOLO("yolov8n.pt")

# 비디오 파일 경로 설정
video_path = "data/sample1.mp4"  # 여기에 실제 비디오 파일 경로를 입력하세요

# 비디오 캡처 객체 생성
cap = cv2.VideoCapture(video_path)

# 추적을 위한 설정
track_history = {}

while cap.isOpened():
    # 프레임 읽기
    success, frame = cap.read()
    if not success:
        print("비디오를 읽을 수 없습니다.")
        break

    # YOLOv8 추적 실행
    results = model.track(frame, persist=True)

    # 결과 시각화
    annotated_frame = results[0].plot()

    # 추적 결과 처리
    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xywh.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()

        for box, track_id in zip(boxes, track_ids):
            x, y, w, h = box
            track = track_history.get(track_id, [])
            track.append((float(x), float(y)))  # 중심점 저장
            track_history[track_id] = track[-30:]  # 최대 30개의 점만 유지

            # 추적 경로 그리기
            if len(track) > 1:
                points = np.array(track, dtype=np.int32)
                cv2.polylines(
                    annotated_frame,
                    [points],
                    isClosed=False,
                    color=(0, 255, 0),
                    thickness=2,
                )

    # 결과 표시
    cv2.imshow("YOLOv8 Tracking", annotated_frame)

    # 'q' 키를 누르면 종료
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# 리소스 해제
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 512x640 3 baseball gloves, 54.8ms
# Speed: 4.5ms preprocess, 54.8ms inference, 7.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 52.8ms
# Speed: 1.5ms preprocess, 52.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 41.5ms
# Speed: 1.1ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 39.0ms
# Speed: 1.4ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.5ms
# Speed: 1.6ms preprocess, 36.5ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 40.9ms
# Speed: 5.6ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.8ms
# Speed: 1.0ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 41.0ms
# Speed: 1.1ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.0ms
# Speed: 1.2ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 40.1ms
# Speed: 1.4ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.4ms
# Speed: 1.6ms preprocess, 33.4ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.6ms
# Speed: 1.2ms preprocess, 36.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.4ms
# Speed: 1.1ms preprocess, 34.4ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.5ms
# Speed: 1.4ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 53.9ms
# Speed: 2.1ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.3ms
# Speed: 1.0ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.6ms
# Speed: 1.3ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 40.0ms
# Speed: 1.3ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.0ms
# Speed: 1.3ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 40.5ms
# Speed: 1.1ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.9ms
# Speed: 1.4ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.8ms
# Speed: 0.9ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 39.8ms
# Speed: 1.4ms preprocess, 39.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.7ms
# Speed: 1.3ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 42.5ms
# Speed: 1.6ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.4ms
# Speed: 1.0ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.7ms
# Speed: 1.2ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 32.0ms
# Speed: 1.2ms preprocess, 32.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 39.6ms
# Speed: 1.1ms preprocess, 39.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.9ms
# Speed: 1.6ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 39.1ms
# Speed: 1.1ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 46.1ms
# Speed: 1.6ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.0ms
# Speed: 1.0ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 41.6ms
# Speed: 1.2ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 40.0ms
# Speed: 1.3ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.5ms
# Speed: 1.1ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.3ms
# Speed: 1.3ms preprocess, 37.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 32.2ms
# Speed: 1.3ms preprocess, 32.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.9ms
# Speed: 1.4ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.8ms
# Speed: 1.0ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.6ms
# Speed: 1.2ms preprocess, 36.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.2ms
# Speed: 1.3ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.3ms
# Speed: 1.4ms preprocess, 35.3ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 42.9ms
# Speed: 1.4ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 39.2ms
# Speed: 1.4ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.4ms
# Speed: 1.1ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.4ms
# Speed: 2.3ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.3ms
# Speed: 0.9ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.2ms
# Speed: 1.2ms preprocess, 36.2ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 40.6ms
# Speed: 1.4ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 41.0ms
# Speed: 1.8ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.8ms
# Speed: 1.2ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.6ms
# Speed: 1.0ms preprocess, 33.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 39.5ms
# Speed: 1.4ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 40.6ms
# Speed: 1.0ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.1ms
# Speed: 1.1ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.9ms
# Speed: 1.1ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 44.2ms
# Speed: 1.2ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.1ms
# Speed: 1.1ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.5ms
# Speed: 1.6ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.9ms
# Speed: 1.4ms preprocess, 34.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.0ms
# Speed: 1.1ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 41.5ms
# Speed: 1.1ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.0ms
# Speed: 1.1ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.9ms
# Speed: 1.5ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 39.5ms
# Speed: 0.9ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.0ms
# Speed: 1.1ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.7ms
# Speed: 1.1ms preprocess, 36.7ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.6ms
# Speed: 0.9ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.1ms
# Speed: 1.2ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.4ms
# Speed: 1.4ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.8ms
# Speed: 1.3ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.9ms
# Speed: 1.0ms preprocess, 33.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 39.5ms
# Speed: 1.3ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.5ms
# Speed: 1.0ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.0ms
# Speed: 0.9ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.1ms
# Speed: 1.8ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.0ms
# Speed: 1.3ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.3ms
# Speed: 1.3ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 32.1ms
# Speed: 1.2ms preprocess, 32.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.8ms
# Speed: 1.5ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 32.4ms
# Speed: 1.6ms preprocess, 32.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.6ms
# Speed: 1.1ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.0ms
# Speed: 1.2ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.3ms
# Speed: 1.5ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 39.5ms
# Speed: 1.3ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.0ms
# Speed: 1.4ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.8ms
# Speed: 1.3ms preprocess, 35.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.9ms
# Speed: 1.5ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.7ms
# Speed: 1.4ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 33.1ms
# Speed: 1.3ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 39.8ms
# Speed: 1.4ms preprocess, 39.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 1 dog, 2 baseball gloves, 36.0ms
# Speed: 1.5ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 1 dog, 1 baseball glove, 1 banana, 33.5ms
# Speed: 1.1ms preprocess, 33.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 1 dog, 2 baseball gloves, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 3 baseball gloves, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 1 sheep, 3 baseball gloves, 33.3ms
# Speed: 1.1ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 dogs, 3 baseball gloves, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 dogs, 3 baseball gloves, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 3 baseball gloves, 35.3ms
# Speed: 1.4ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 2 baseball gloves, 47.9ms
# Speed: 1.0ms preprocess, 47.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 1 baseball glove, 46.2ms
# Speed: 1.4ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 1 baseball glove, 1 teddy bear, 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 2 baseball gloves, 40.0ms
# Speed: 1.0ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 2 baseball gloves, 34.5ms
# Speed: 1.2ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 2 baseball gloves, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 2 baseball gloves, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 baseball gloves, 35.3ms
# Speed: 1.8ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 36.8ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 baseball gloves, 34.1ms
# Speed: 1.3ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 36.7ms
# Speed: 1.4ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 52.7ms
# Speed: 1.0ms preprocess, 52.7ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 33.3ms
# Speed: 1.5ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.1ms
# Speed: 0.9ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.1ms
# Speed: 1.3ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.9ms
# Speed: 1.4ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.1ms
# Speed: 1.1ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 36.0ms
# Speed: 1.4ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sports ball, 1 baseball glove, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sports ball, 1 baseball glove, 32.2ms
# Speed: 1.1ms preprocess, 32.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 37.2ms
# Speed: 1.3ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 1 baseball glove, 33.8ms
# Speed: 1.1ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 1 baseball glove, 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.1ms
# Speed: 1.0ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 36.4ms
# Speed: 1.2ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 baseball gloves, 33.7ms
# Speed: 0.9ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 baseball gloves, 34.7ms
# Speed: 1.9ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 34.4ms
# Speed: 1.0ms preprocess, 34.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.1ms
# Speed: 1.1ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 34.2ms
# Speed: 1.3ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 37.7ms
# Speed: 0.9ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.2ms
# Speed: 1.3ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.4ms
# Speed: 1.4ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 36.5ms
# Speed: 1.0ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 33.8ms
# Speed: 1.0ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 fire hydrant, 2 baseball gloves, 33.6ms
# Speed: 1.2ms preprocess, 33.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 fire hydrant, 2 baseball gloves, 32.8ms
# Speed: 2.5ms preprocess, 32.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 fire hydrant, 1 sports ball, 1 baseball glove, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 sports ball, 1 baseball glove, 32.0ms
# Speed: 1.4ms preprocess, 32.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 sports ball, 1 baseball glove, 35.6ms
# Speed: 0.9ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 sports ball, 2 baseball gloves, 35.9ms
# Speed: 1.3ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 3 baseball gloves, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 3 baseball gloves, 33.7ms
# Speed: 1.2ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 sports ball, 3 baseball gloves, 36.1ms
# Speed: 1.3ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sheep, 1 sports ball, 2 baseball gloves, 34.3ms
# Speed: 1.4ms preprocess, 34.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sports ball, 2 baseball gloves, 33.8ms
# Speed: 1.4ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sports ball, 2 baseball gloves, 38.8ms
# Speed: 1.3ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 sports balls, 1 baseball glove, 37.6ms
# Speed: 1.4ms preprocess, 37.6ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.6ms
# Speed: 1.2ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 36.3ms
# Speed: 1.2ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 sports balls, 1 baseball glove, 35.0ms
# Speed: 1.1ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sheep, 2 sports balls, 1 baseball glove, 34.4ms
# Speed: 1.1ms preprocess, 34.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 1 sheep, 2 baseball gloves, 33.8ms
# Speed: 1.4ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 birds, 2 baseball gloves, 32.6ms
# Speed: 1.0ms preprocess, 32.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 bird, 1 sheep, 3 baseball gloves, 35.1ms
# Speed: 0.9ms preprocess, 35.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 40.1ms
# Speed: 1.3ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 34.5ms
# Speed: 1.4ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.0ms
# Speed: 1.3ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 38.1ms
# Speed: 1.3ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 33.9ms
# Speed: 1.1ms preprocess, 33.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 dogs, 2 baseball gloves, 1 teddy bear, 37.3ms
# Speed: 1.1ms preprocess, 37.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 persons, 2 dogs, 1 baseball glove, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 34.7ms
# Speed: 1.7ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 36.6ms
# Speed: 1.0ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 baseball glove, 35.0ms
# Speed: 1.5ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 baseball gloves, 32.8ms
# Speed: 1.0ms preprocess, 32.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 baseball gloves, 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 sheep, 2 baseball gloves, 35.8ms
# Speed: 1.3ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 sheep, 2 baseball gloves, 33.4ms
# Speed: 1.1ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 baseball gloves, 32.7ms
# Speed: 1.1ms preprocess, 32.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 dog, 2 baseball gloves, 34.2ms
# Speed: 1.4ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 dog, 2 baseball gloves, 38.4ms
# Speed: 1.3ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 baseball gloves, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 baseball gloves, 35.6ms
# Speed: 1.4ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 34.0ms
# Speed: 1.0ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 31.8ms
# Speed: 1.0ms preprocess, 31.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 3 baseball gloves, 33.7ms
# Speed: 1.1ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 sheep, 2 baseball gloves, 32.5ms
# Speed: 1.2ms preprocess, 32.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 sheep, 2 baseball gloves, 34.8ms
# Speed: 1.2ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 baseball glove, 32.8ms
# Speed: 1.0ms preprocess, 32.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 baseball glove, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 39.3ms
# Speed: 1.5ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 40.4ms
# Speed: 0.9ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 36.3ms
# Speed: 1.0ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 1 baseball glove, 38.0ms
# Speed: 1.4ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 1 baseball glove, 36.4ms
# Speed: 1.6ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 35.8ms
# Speed: 0.9ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 fire hydrant, 2 baseball gloves, 35.0ms
# Speed: 0.9ms preprocess, 35.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 32.8ms
# Speed: 1.0ms preprocess, 32.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 32.9ms
# Speed: 1.0ms preprocess, 32.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.4ms
# Speed: 1.6ms preprocess, 36.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 3 baseball gloves, 37.8ms
# Speed: 1.1ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 1 sports ball, 2 baseball gloves, 37.4ms
# Speed: 1.0ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 3 baseball gloves, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 2 baseball gloves, 31.8ms
# Speed: 1.6ms preprocess, 31.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 2 baseball gloves, 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 33.0ms
# Speed: 1.1ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 38.5ms
# Speed: 1.6ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 2 baseball gloves, 32.8ms
# Speed: 1.3ms preprocess, 32.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 2 baseball gloves, 35.7ms
# Speed: 1.7ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 2 baseball gloves, 33.6ms
# Speed: 1.1ms preprocess, 33.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 35.1ms
# Speed: 1.3ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 bottle, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 bottle, 33.3ms
# Speed: 0.9ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 bottle, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 baseball gloves, 40.0ms
# Speed: 1.0ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 bottle, 32.2ms
# Speed: 1.0ms preprocess, 32.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 48.9ms
# Speed: 1.1ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.8ms
# Speed: 1.3ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.1ms
# Speed: 0.9ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 32.6ms
# Speed: 1.2ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sports ball, 2 baseball gloves, 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sports ball, 2 baseball gloves, 33.2ms
# Speed: 1.1ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 36.3ms
# Speed: 1.5ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.8ms
# Speed: 0.9ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 38.3ms
# Speed: 1.7ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 3 baseball gloves, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.1ms
# Speed: 1.1ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 35.4ms
# Speed: 1.4ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 35.3ms
# Speed: 1.4ms preprocess, 35.3ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 34.7ms
# Speed: 1.8ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sheep, 2 baseball gloves, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sheep, 2 baseball gloves, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 32.9ms
# Speed: 1.3ms preprocess, 32.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 39.2ms
# Speed: 1.0ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 baseball gloves, 32.0ms
# Speed: 1.7ms preprocess, 32.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 36.3ms
# Speed: 1.3ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 1 baseball glove, 34.4ms
# Speed: 1.4ms preprocess, 34.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 sports ball, 34.7ms
# Speed: 1.3ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 50.9ms
# Speed: 1.1ms preprocess, 50.9ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 baseball glove, 37.3ms
# Speed: 1.0ms preprocess, 37.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 3 dogs, 1 horse, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 horse, 32.3ms
# Speed: 1.0ms preprocess, 32.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 horse, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 baseball glove, 35.1ms
# Speed: 1.8ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 baseball glove, 35.7ms
# Speed: 0.9ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 baseball glove, 35.1ms
# Speed: 1.3ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 baseball glove, 36.5ms
# Speed: 1.1ms preprocess, 36.5ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 cow, 1 baseball glove, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 42.6ms
# Speed: 2.6ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 dog, 2 baseball gloves, 34.9ms
# Speed: 1.6ms preprocess, 34.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 38.2ms
# Speed: 1.3ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 33.8ms
# Speed: 1.0ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 35.1ms
# Speed: 1.4ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.5ms
# Speed: 1.9ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 40.9ms
# Speed: 1.4ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 34.1ms
# ...
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.5ms
# Speed: 1.6ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 36.7ms
# Speed: 1.5ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 40.1ms
# Speed: 1.1ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.8ms
# Speed: 1.1ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.4ms
# Speed: 1.1ms preprocess, 34.4ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 38.1ms
# Speed: 1.8ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.1ms
# Speed: 1.2ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.5ms
# Speed: 0.8ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 37.1ms
# Speed: 1.7ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.2ms
# Speed: 1.6ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 33.4ms
# Speed: 1.1ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 33.3ms
# Speed: 1.3ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 33.4ms
# Speed: 1.1ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 47.8ms
# Speed: 1.4ms preprocess, 47.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 38.7ms
# Speed: 1.2ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.3ms
# Speed: 1.3ms preprocess, 34.3ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 36.7ms
# Speed: 1.5ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 47.8ms
# Speed: 1.3ms preprocess, 47.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.9ms
# Speed: 1.4ms preprocess, 34.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.3ms
# Speed: 0.9ms preprocess, 34.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 41.0ms
# Speed: 1.8ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.2ms
# Speed: 1.1ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 35.1ms
# Speed: 5.5ms preprocess, 35.1ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 37.1ms
# Speed: 1.5ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 47.7ms
# Speed: 1.0ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 35.3ms
# Speed: 1.5ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 35.4ms
# Speed: 1.4ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 38.4ms
# Speed: 1.5ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 37.9ms
# Speed: 1.2ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 36.8ms
# Speed: 1.3ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 40.0ms
# Speed: 1.0ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 53.3ms
# Speed: 0.9ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 37.2ms
# Speed: 1.1ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 36.3ms
# Speed: 1.2ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.2ms
# Speed: 1.0ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 38.7ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 47.5ms
# Speed: 1.0ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 38.8ms
# Speed: 1.2ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.0ms
# Speed: 1.3ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.8ms
# Speed: 1.1ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.8ms
# Speed: 1.0ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 62.5ms
# Speed: 1.6ms preprocess, 62.5ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 66.4ms
# Speed: 1.4ms preprocess, 66.4ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 56.2ms
# Speed: 1.0ms preprocess, 56.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 50.1ms
# Speed: 1.5ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 48.4ms
# Speed: 1.7ms preprocess, 48.4ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 44.5ms
# Speed: 1.8ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 41.6ms
# Speed: 1.6ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 42.6ms
# Speed: 1.7ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 37.0ms
# Speed: 1.0ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.1ms
# Speed: 1.2ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 43.8ms
# Speed: 1.2ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 80.9ms
# Speed: 1.1ms preprocess, 80.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 44.8ms
# Speed: 1.5ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 baseball gloves, 1 teddy bear, 38.8ms
# Speed: 1.4ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
# 비디오를 읽을 수 없습니다.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
