# %%
import cv2
import numpy as np

def preprocess_image(image_path):
    # Load the image using OpenCV
    img = cv2.imread(image_path)

    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply image enhancement algorithms (e.g. contrast stretching, histogram equalization)

    # Resize the image to a fixed size
    resized = cv2.resize(gray, (128, 32))

    # Normalize the pixel values to the range [0, 1]
    normalized = np.array(resized) / 255.0

    # Add an additional channel dimension for compatibility with CNN models
    reshaped = np.reshape(normalized, (normalized.shape[0], normalized.shape[1], 1))

    return reshaped

# %%
import tensorflow as tf

def create_model(input_shape, num_classes):
    # Define the CNN architecture
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=128, activation='relu'),
        tf.keras.layers.Dense(units=num_classes, activation='softmax')
    ])

    return model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/__init__.py:22, in <module>
#      21 try:
# ---> 22     from . import multiarray
#      23 except ImportError as exc:
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/multiarray.py:12, in <module>
#      10 import warnings
# ---> 12 from . import overrides
#      13 from . import _multiarray_umath
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/overrides.py:7, in <module>
#       5 import textwrap
# ----> 7 from numpy.core._multiarray_umath import (
#       8     add_docstring, implement_array_function, _get_implementing_args)
#       9 from numpy.compat._inspect import getargspec
#
# ImportError: dlopen(/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/_multiarray_umath.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/libcblas.3.dylib
#   Referenced from: <040ADDAA-0BD4-352D-8E85-E3ABB073DD73> /Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/_multiarray_umath.cpython-39-darwin.so
#   Reason: tried: '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/../../../../libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/../../../../libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/bin/../lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/bin/../lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS@rpath/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/../../../../libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/../../../../libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/bin/../lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/bin/../lib/libcblas.3.dylib' (no such file), '/usr/local/lib/libcblas.3.dylib' (no such file), '/usr/lib/libcblas.3.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 import tensorflow as tf
#       3 def create_model(input_shape, num_classes):
#       4     # Define the CNN architecture
#       5     model = tf.keras.models.Sequential([
#       6         tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
#       7         tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
#    (...)
#      12         tf.keras.layers.Dense(units=num_classes, activation='softmax')
#      13     ])
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/__init__.py:41, in <module>
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/__init__.py:40, in <module>
#      31 import traceback
#      33 # We aim to keep this file minimal and ideally remove completely.
#      34 # If you are adding a new file with @tf_export decorators,
#      35 # import it in modules_with_exports.py instead.
#      36
#      37 # go/tf-wildcard-import
#      38 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
# ---> 40 from tensorflow.python.eager import context
#      41 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      43 # pylint: enable=wildcard-import
#      44
#      45 # Bring in subpackages.
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/context.py:29, in <module>
#      26 import threading
#      28 from absl import logging
# ---> 29 import numpy as np
#      30 import six
#      32 from tensorflow.core.framework import function_pb2
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/__init__.py:140, in <module>
#     137 # Allow distributors to run custom init code
#     138 from . import _distributor_init
# --> 140 from . import core
#     141 from .core import *
#     142 from . import compat
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/__init__.py:48, in <module>
#      24     import sys
#      25     msg = """
#      26
#      27 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      46 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      47         __version__, exc)
# ---> 48     raise ImportError(msg)
#      49 finally:
#      50     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.9 from "/Users/syshin/miniforge3/envs/tensorflow/bin/python"
#   * The NumPy version is: "1.19.5"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/_multiarray_umath.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/libcblas.3.dylib
#   Referenced from: <040ADDAA-0BD4-352D-8E85-E3ABB073DD73> /Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/_multiarray_umath.cpython-39-darwin.so
#   Reason: tried: '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/../../../../libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/../../../../libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/bin/../lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/bin/../lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS@rpath/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/../../../../libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/syshin/miniforge3/envs/tensorflow/lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/numpy/core/../../../../libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/bin/../lib/libcblas.3.dylib' (no such file), '/Users/syshin/miniforge3/envs/tensorflow/bin/../lib/libcblas.3.dylib' (no such file), '/usr/local/lib/libcblas.3.dylib' (no such file), '/usr/lib/libcblas.3.dylib' (no such file, not in dyld cache)

# %%
def train_model(model, train_data, train_labels, val_data, val_labels, batch_size, epochs):
    # Compile the model with an appropriate loss function and optimizer
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Train the model on the training data
    history = model.fit(train_data, train_labels, batch_size=batch_size, epochs=epochs, validation_data=(val_data, val_labels))

    return history

# %%
def predict(model, image_path, character_mapping):
    # Preprocess the input image
    input_image = preprocess_image(image_path)

    # Make a prediction using the trained model
    prediction = model.predict(np.array([input_image]))

    # Convert the output from a probability distribution to a predicted character
    predicted_index = np.argmax(prediction)
    predicted_character = character_mapping[predicted_index]

    return predicted_character

# %%
# !pip install --force-reinstall numpy
# Out:
# Collecting numpy
#   Downloading numpy-1.24.2-cp39-cp39-macosx_11_0_arm64.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 42.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
# Successfully installed numpy-1.24.2
#
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !conda update --all
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/osx-arm64::nb_conda==2.2.1=py39h2804cbe_4
#   - conda-forge/noarch::notebook-shim==0.1.0=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::jupyter==1.0.0=py39h2804cbe_7
#   - conda-forge/osx-arm64::widgetsnbextension==3.6.0=py39h2804cbe_0
#   - conda-forge/noarch::ipywidgets==7.7.0=pyhd8ed1ab_0
#   - apple/osx-arm64::tensorflow-deps==2.9.0=0
#   - conda-forge/noarch::jupyterlab==3.4.2=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::anyio==3.6.1=py39h2804cbe_0
#   - conda-forge/noarch::jupyterlab_server==2.13.0=pyhd8ed1ab_1
#   - conda-forge/noarch::notebook==6.4.11=pyha770c72_0
#   - conda-forge/osx-arm64::nbconvert==6.4.5=py39h2804cbe_0
#   - conda-forge/osx-arm64::conda==4.12.0=py39h2804cbe_0
#   - conda-forge/noarch::jupyter_server==1.16.0=pyhd8ed1ab_0
#   - conda-forge/noarch::nbclassic==0.3.7=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::h5py==3.6.0=nompi_py39hd982b79_100
# failed with repodata from current_repodata.json, will retry with next repodata source.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/osx-arm64::nb_conda==2.2.1=py39h2804cbe_4
#   - conda-forge/noarch::notebook-shim==0.1.0=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::jupyter==1.0.0=py39h2804cbe_7
#   - conda-forge/osx-arm64::widgetsnbextension==3.6.0=py39h2804cbe_0
#   - conda-forge/noarch::ipywidgets==7.7.0=pyhd8ed1ab_0
#   - apple/osx-arm64::tensorflow-deps==2.9.0=0
#   - conda-forge/noarch::jupyterlab==3.4.2=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::anyio==3.6.1=py39h2804cbe_0
#   - conda-forge/noarch::jupyterlab_server==2.13.0=pyhd8ed1ab_1
#   - conda-forge/noarch::notebook==6.4.11=pyha770c72_0
#   - conda-forge/osx-arm64::nbconvert==6.4.5=py39h2804cbe_0
#   - conda-forge/osx-arm64::conda==4.12.0=py39h2804cbe_0
#   - conda-forge/noarch::jupyter_server==1.16.0=pyhd8ed1ab_0
#   - conda-forge/noarch::nbclassic==0.3.7=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::h5py==3.6.0=nompi_py39hd982b79_100
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/syshin/miniforge3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     adwaita-icon-theme-40.1.1  |       hca03da5_1        10.6 MB
#     attrs-22.1.0               |   py39hca03da5_0          84 KB
#     babel-2.11.0               |   py39hca03da5_0         6.8 MB
#     blas-2.114                 |         openblas          13 KB  conda-forge
#     blas-devel-3.9.0           |14_osxarm64_openblas          12 KB  conda-forge
#     boltons-23.0.0             |   py39hca03da5_0         429 KB
#     c-ares-1.19.0              |       h80987f9_0         104 KB
#     ca-certificates-2023.01.10 |       hca03da5_0         121 KB
#     cffi-1.15.1                |   py39h80987f9_3         231 KB
#     comm-0.1.2                 |   py39hca03da5_0          14 KB
#     conda-23.3.1               |   py39hca03da5_0         963 KB
#     conda-package-handling-2.0.2|   py39hca03da5_0         269 KB
#     conda-package-streaming-0.7.0|   py39hca03da5_0          27 KB
#     cryptography-39.0.1        |   py39h834c97f_0         1.1 MB
#     dbus-1.13.18               |       h8280c03_0         1.4 MB
#     epoxy-1.5.4                |       h1a28f6b_2         344 KB
#     flit-core-3.8.0            |   py39hca03da5_0          86 KB
#     gdk-pixbuf-2.42.10         |       h80987f9_0         581 KB
#     giflib-5.2.1               |       h80987f9_3          78 KB
#     glib-2.69.1                |       h514c7bf_2         3.0 MB
#     gobject-introspection-1.72.0|   py39hddb4ab5_2         1.5 MB
#     gtk3-3.24.21               |       h67936d1_5         7.7 MB
#     harfbuzz-4.3.0             |       he9eebac_1         1.1 MB
#     hicolor-icon-theme-0.17    |       hca03da5_2          15 KB
#     importlib-metadata-6.0.0   |   py39hca03da5_0          40 KB
#     importlib_metadata-6.0.0   |       hd3eb1b0_0           8 KB
#     ipykernel-6.19.2           |   py39h86d0a89_0         219 KB
#     ipython-8.10.0             |   py39hca03da5_0         1.1 MB
#     jpeg-9e                    |       h80987f9_1         248 KB
#     jsonpatch-1.32             |     pyhd3eb1b0_0          15 KB
#     jsonpointer-2.1            |     pyhd3eb1b0_0           9 KB
#     jsonschema-4.17.3          |   py39hca03da5_0         142 KB
#     jupyter-1.0.0              |   py39hca03da5_8           8 KB
#     jupyter_client-8.1.0       |   py39hca03da5_0         183 KB
#     jupyter_console-6.6.3      |   py39hca03da5_0          46 KB
#     jupyter_core-5.3.0         |   py39hca03da5_0          90 KB
#     krb5-1.19.4                |       h8380606_0         1.2 MB
#     libcurl-7.88.1             |       h0f1d93c_0         332 KB
#     libedit-3.1.20221030       |       h80987f9_0         154 KB
#     libevent-2.1.12            |       hf27765b_0         360 KB
#     liblapacke-3.9.0           |14_osxarm64_openblas          12 KB  conda-forge
#     libpng-1.6.39              |       h80987f9_0         283 KB
#     libpq-12.9                 |       h65cfe13_3         2.0 MB
#     libwebp-1.2.4              |       ha3663a8_1          86 KB
#     libwebp-base-1.2.4         |       h80987f9_1         293 KB
#     nbformat-5.7.0             |   py39hca03da5_0         134 KB
#     ncurses-6.4                |       h313beb8_0         884 KB
#     nest-asyncio-1.5.6         |   py39hca03da5_0          16 KB
#     nspr-4.33                  |       hc377ac9_0         222 KB
#     nss-3.74                   |       h142855e_0         1.7 MB
#     numpy-1.22.3               |   py39h25ab29e_0          11 KB
#     numpy-base-1.22.3          |   py39h974a1f5_0         4.6 MB
#     openblas-0.3.20            |openmp_h745f6c2_0         4.2 MB  conda-forge
#     openssl-1.1.1t             |       h1a28f6b_0         2.6 MB
#     packaging-23.0             |   py39hca03da5_0          70 KB
#     pip-23.0.1                 |   py39hca03da5_0         2.5 MB
#     prompt-toolkit-3.0.36      |   py39hca03da5_0         567 KB
#     prompt_toolkit-3.0.36      |       hd3eb1b0_0           5 KB
#     pyopenssl-23.0.0           |   py39hca03da5_0          98 KB
#     pyqt-5.15.2                |   py39he8f2410_0         4.3 MB
#     python-3.9.16              |       hc0d8a6c_2        12.6 MB
#     pytz-2022.7                |   py39hca03da5_0         211 KB
#     qt-5.15.2                  |       h4e944ae_2        31.6 MB
#     qtconsole-5.4.0            |   py39hca03da5_0         192 KB
#     qtpy-2.2.0                 |   py39hca03da5_0          85 KB
#     requests-2.28.1            |   py39hca03da5_1         101 KB
#     ruamel.yaml-0.17.21        |   py39h1a28f6b_0         178 KB
#     ruamel.yaml.clib-0.2.6     |   py39h1a28f6b_1         116 KB
#     setuptools-65.6.3          |   py39hca03da5_0         1.2 MB
#     sqlite-3.41.1              |       h80987f9_0         1.1 MB
#     terminado-0.17.1           |   py39hca03da5_0          33 KB
#     tqdm-4.65.0                |   py39h86d0a89_0         133 KB
#     traitlets-5.7.1            |   py39hca03da5_0         205 KB
#     typing-extensions-4.4.0    |   py39hca03da5_0           9 KB
#     typing_extensions-4.4.0    |   py39hca03da5_0          47 KB
#     urllib3-1.26.15            |   py39hca03da5_0         199 KB
#     wheel-0.38.4               |   py39hca03da5_0          65 KB
#     xz-5.2.10                  |       h80987f9_1         263 KB
#     zipp-3.11.0                |   py39hca03da5_0          20 KB
#     zstandard-0.19.0           |   py39h80987f9_0         368 KB
#     ------------------------------------------------------------
#                                            Total:       113.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   adwaita-icon-theme pkgs/main/osx-arm64::adwaita-icon-theme-40.1.1-hca03da5_1
#   atk-1.0            pkgs/main/osx-arm64::atk-1.0-2.36.0-h7fe96df_0
#   blas               conda-forge/osx-arm64::blas-2.114-openblas
#   blas-devel         conda-forge/osx-arm64::blas-devel-3.9.0-14_osxarm64_openblas
#   boltons            pkgs/main/osx-arm64::boltons-23.0.0-py39hca03da5_0
#   cairo              pkgs/main/osx-arm64::cairo-1.16.0-h29d4eff_2
#   certifi            pkgs/main/osx-arm64::certifi-2022.12.7-py39hca03da5_0
#   comm               pkgs/main/osx-arm64::comm-0.1.2-py39hca03da5_0
#   conda-package-str~ pkgs/main/osx-arm64::conda-package-streaming-0.7.0-py39hca03da5_0
#   dbus               pkgs/main/osx-arm64::dbus-1.13.18-h8280c03_0
#   epoxy              pkgs/main/osx-arm64::epoxy-1.5.4-h1a28f6b_2
#   expat              pkgs/main/osx-arm64::expat-2.4.9-hc377ac9_0
#   fontconfig         pkgs/main/osx-arm64::fontconfig-2.13.1-h1f4a5ec_0
#   freetype           pkgs/main/osx-arm64::freetype-2.12.1-h1192e45_0
#   fribidi            pkgs/main/osx-arm64::fribidi-1.0.10-h1a28f6b_0
#   gdk-pixbuf         pkgs/main/osx-arm64::gdk-pixbuf-2.42.10-h80987f9_0
#   gettext            pkgs/main/osx-arm64::gettext-0.21.0-h826f4ad_0
#   giflib             pkgs/main/osx-arm64::giflib-5.2.1-h80987f9_3
#   glib               pkgs/main/osx-arm64::glib-2.69.1-h514c7bf_2
#   gobject-introspec~ pkgs/main/osx-arm64::gobject-introspection-1.72.0-py39hddb4ab5_2
#   graphite2          pkgs/main/osx-arm64::graphite2-1.3.14-hc377ac9_1
#   gtk3               pkgs/main/osx-arm64::gtk3-3.24.21-h67936d1_5
#   harfbuzz           pkgs/main/osx-arm64::harfbuzz-4.3.0-he9eebac_1
#   hicolor-icon-theme pkgs/main/osx-arm64::hicolor-icon-theme-0.17-hca03da5_2
#   icu                pkgs/main/osx-arm64::icu-68.1-hc377ac9_0
#   idna               pkgs/main/osx-arm64::idna-3.4-py39hca03da5_0
#   jinja2             pkgs/main/osx-arm64::jinja2-3.1.2-py39hca03da5_0
#   jpeg               pkgs/main/osx-arm64::jpeg-9e-h80987f9_1
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd3eb1b0_0
#   jsonpointer        pkgs/main/noarch::jsonpointer-2.1-pyhd3eb1b0_0
#   libevent           pkgs/main/osx-arm64::libevent-2.1.12-hf27765b_0
#   libiconv           pkgs/main/osx-arm64::libiconv-1.16-h1a28f6b_2
#   liblapacke         conda-forge/osx-arm64::liblapacke-3.9.0-14_osxarm64_openblas
#   libpng             pkgs/main/osx-arm64::libpng-1.6.39-h80987f9_0
#   libpq              pkgs/main/osx-arm64::libpq-12.9-h65cfe13_3
#   librsvg            pkgs/main/osx-arm64::librsvg-2.50.7-h90a7944_0
#   libtiff            pkgs/main/osx-arm64::libtiff-4.2.0-h11e2f9f_0
#   libwebp            pkgs/main/osx-arm64::libwebp-1.2.4-ha3663a8_1
#   libwebp-base       pkgs/main/osx-arm64::libwebp-base-1.2.4-h80987f9_1
#   libxml2            pkgs/main/osx-arm64::libxml2-2.9.12-h8c5e841_0
#   libxslt            pkgs/main/osx-arm64::libxslt-1.1.34-h9833966_0
#   lz4-c              pkgs/main/osx-arm64::lz4-c-1.9.3-hc377ac9_0
#   markupsafe         pkgs/main/osx-arm64::markupsafe-2.1.1-py39h1a28f6b_0
#   ninja              pkgs/main/osx-arm64::ninja-1.10.2-hca03da5_5
#   ninja-base         pkgs/main/osx-arm64::ninja-base-1.10.2-h525c30c_5
#   nspr               pkgs/main/osx-arm64::nspr-4.33-hc377ac9_0
#   nss                pkgs/main/osx-arm64::nss-3.74-h142855e_0
#   numpy              pkgs/main/osx-arm64::numpy-1.22.3-py39h25ab29e_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.22.3-py39h974a1f5_0
#   openblas           conda-forge/osx-arm64::openblas-0.3.20-openmp_h745f6c2_0
#   pango              pkgs/main/osx-arm64::pango-1.50.7-h7271ec9_0
#   pcre               pkgs/main/osx-arm64::pcre-8.45-hc377ac9_0
#   pip                pkgs/main/osx-arm64::pip-23.0.1-py39hca03da5_0
#   pixman             pkgs/main/osx-arm64::pixman-0.40.0-h1a28f6b_0
#   platformdirs       pkgs/main/osx-arm64::platformdirs-2.5.2-py39hca03da5_0
#   pluggy             pkgs/main/osx-arm64::pluggy-1.0.0-py39hca03da5_1
#   pyqt               pkgs/main/osx-arm64::pyqt-5.15.2-py39he8f2410_0
#   qt                 pkgs/main/osx-arm64::qt-5.15.2-h4e944ae_2
#   qtconsole          pkgs/main/osx-arm64::qtconsole-5.4.0-py39hca03da5_0
#   qtpy               pkgs/main/osx-arm64::qtpy-2.2.0-py39hca03da5_0
#   requests           pkgs/main/osx-arm64::requests-2.28.1-py39hca03da5_1
#   ruamel.yaml        pkgs/main/osx-arm64::ruamel.yaml-0.17.21-py39h1a28f6b_0
#   ruamel.yaml.clib   pkgs/main/osx-arm64::ruamel.yaml.clib-0.2.6-py39h1a28f6b_1
#   toolz              pkgs/main/osx-arm64::toolz-0.12.0-py39hca03da5_0
#   typing-extensions  pkgs/main/osx-arm64::typing-extensions-4.4.0-py39hca03da5_0
#   typing_extensions  pkgs/main/osx-arm64::typing_extensions-4.4.0-py39hca03da5_0
#   urllib3            pkgs/main/osx-arm64::urllib3-1.26.15-py39hca03da5_0
#   zstandard          pkgs/main/osx-arm64::zstandard-0.19.0-py39h80987f9_0
#   zstd               pkgs/main/osx-arm64::zstd-1.4.9-h8574219_1
#
# The following packages will be UPDATED:
#
#   attrs              conda-forge/noarch::attrs-21.4.0-pyhd~ --> pkgs/main/osx-arm64::attrs-22.1.0-py39hca03da5_0
#   babel              conda-forge/noarch::babel-2.10.1-pyhd~ --> pkgs/main/osx-arm64::babel-2.11.0-py39hca03da5_0
#   c-ares              conda-forge::c-ares-1.18.1-h3422bc3_0 --> pkgs/main::c-ares-1.19.0-h80987f9_0
#   ca-certificates                      2022.4.26-hca03da5_0 --> 2023.01.10-hca03da5_0
#   cffi               conda-forge::cffi-1.15.0-py39h52b1de0~ --> pkgs/main::cffi-1.15.1-py39h80987f9_3
#   conda              conda-forge::conda-4.12.0-py39h2804cb~ --> pkgs/main::conda-23.3.1-py39hca03da5_0
#   conda-package-han~ conda-forge::conda-package-handling-1~ --> pkgs/main::conda-package-handling-2.0.2-py39hca03da5_0
#   cryptography       conda-forge::cryptography-36.0.2-py39~ --> pkgs/main::cryptography-39.0.1-py39h834c97f_0
#   flit-core          conda-forge/noarch::flit-core-3.7.1-p~ --> pkgs/main/osx-arm64::flit-core-3.8.0-py39hca03da5_0
#   importlib-metadata conda-forge::importlib-metadata-4.11.~ --> pkgs/main::importlib-metadata-6.0.0-py39hca03da5_0
#   importlib_metadata conda-forge::importlib_metadata-4.11.~ --> pkgs/main::importlib_metadata-6.0.0-hd3eb1b0_0
#   ipykernel          conda-forge::ipykernel-6.13.0-py39h32~ --> pkgs/main::ipykernel-6.19.2-py39h86d0a89_0
#   ipython            conda-forge::ipython-8.3.0-py39h2804c~ --> pkgs/main::ipython-8.10.0-py39hca03da5_0
#   json5               conda-forge::json5-0.9.5-pyh9f0ad1d_0 --> pkgs/main::json5-0.9.6-pyhd3eb1b0_0
#   jsonschema         conda-forge/noarch::jsonschema-4.5.1-~ --> pkgs/main/osx-arm64::jsonschema-4.17.3-py39hca03da5_0
#   jupyter            conda-forge::jupyter-1.0.0-py39h2804c~ --> pkgs/main::jupyter-1.0.0-py39hca03da5_8
#   jupyter_client     conda-forge/noarch::jupyter_client-7.~ --> pkgs/main/osx-arm64::jupyter_client-8.1.0-py39hca03da5_0
#   jupyter_console    conda-forge/noarch::jupyter_console-6~ --> pkgs/main/osx-arm64::jupyter_console-6.6.3-py39hca03da5_0
#   jupyter_core       conda-forge::jupyter_core-4.10.0-py39~ --> pkgs/main::jupyter_core-5.3.0-py39hca03da5_0
#   krb5                  conda-forge::krb5-1.19.3-hf9b2bbe_0 --> pkgs/main::krb5-1.19.4-h8380606_0
#   libcurl            conda-forge::libcurl-7.83.1-h2fcd78c_0 --> pkgs/main::libcurl-7.88.1-h0f1d93c_0
#   libcxx              conda-forge::libcxx-14.0.3-h6a5c8ee_0 --> pkgs/main::libcxx-14.0.6-h848a8c0_0
#   libedit            conda-forge::libedit-3.1.20191231-hc8~ --> pkgs/main::libedit-3.1.20221030-h80987f9_0
#   libffi               conda-forge::libffi-3.4.2-h3422bc3_5 --> pkgs/main::libffi-3.4.2-hca03da5_6
#   libgfortran        conda-forge::libgfortran-5.0.0.dev0-1~ --> pkgs/main::libgfortran-5.0.0-11_3_0_hca03da5_28
#   libgfortran5       conda-forge::libgfortran5-11.0.1.dev0~ --> pkgs/main::libgfortran5-11.3.0-h009349e_28
#   llvm-openmp        conda-forge::llvm-openmp-14.0.3-hd125~ --> pkgs/main::llvm-openmp-14.0.6-hc6e5704_0
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline~ --> pkgs/main/osx-arm64::matplotlib-inline-0.1.6-py39hca03da5_0
#   nbformat           conda-forge/noarch::nbformat-5.4.0-py~ --> pkgs/main/osx-arm64::nbformat-5.7.0-py39hca03da5_0
#   ncurses               conda-forge::ncurses-6.3-hc470f4d_0 --> pkgs/main::ncurses-6.4-h313beb8_0
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.5.~ --> pkgs/main/osx-arm64::nest-asyncio-1.5.6-py39hca03da5_0
#   openssl                                 1.1.1o-h1a28f6b_0 --> 1.1.1t-h1a28f6b_0
#   packaging          conda-forge/noarch::packaging-21.3-py~ --> pkgs/main/osx-arm64::packaging-23.0-py39hca03da5_0
#   pexpect            conda-forge::pexpect-4.8.0-pyh9f0ad1d~ --> pkgs/main::pexpect-4.8.0-pyhd3eb1b0_3
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.~ --> pkgs/main/osx-arm64::prompt-toolkit-3.0.36-py39hca03da5_0
#   prompt_toolkit     conda-forge::prompt_toolkit-3.0.29-hd~ --> pkgs/main::prompt_toolkit-3.0.36-hd3eb1b0_0
#   ptyprocess         conda-forge::ptyprocess-0.7.0-pyhd3de~ --> pkgs/main::ptyprocess-0.7.0-pyhd3eb1b0_2
#   pycosat            conda-forge::pycosat-0.6.3-py39h51615~ --> pkgs/main::pycosat-0.6.4-py39h1a28f6b_0
#   pyopenssl          conda-forge/noarch::pyopenssl-22.0.0-~ --> pkgs/main/osx-arm64::pyopenssl-23.0.0-py39hca03da5_0
#   python             conda-forge::python-3.9.10-hd16f9c5_2~ --> pkgs/main::python-3.9.16-hc0d8a6c_2
#   python-fastjsonsc~ conda-forge/noarch::python-fastjsonsc~ --> pkgs/main/osx-arm64::python-fastjsonschema-2.16.2-py39hca03da5_0
#   pytz               conda-forge/noarch::pytz-2022.1-pyhd8~ --> pkgs/main/osx-arm64::pytz-2022.7-py39hca03da5_0
#   pyzmq              conda-forge::pyzmq-22.3.0-py39h7a4232~ --> pkgs/main::pyzmq-23.2.0-py39hc377ac9_0
#   readline                                 8.1.2-h1a28f6b_1 --> 8.2-h1a28f6b_0
#   send2trash         conda-forge::send2trash-1.8.0-pyhd8ed~ --> pkgs/main::send2trash-1.8.0-pyhd3eb1b0_1
#   setuptools         conda-forge::setuptools-60.10.0-py39h~ --> pkgs/main::setuptools-65.6.3-py39hca03da5_0
#   soupsieve          conda-forge/noarch::soupsieve-2.3.1-p~ --> pkgs/main/osx-arm64::soupsieve-2.3.2.post1-py39hca03da5_0
#   sqlite              conda-forge::sqlite-3.37.1-h7e3ccbd_0 --> pkgs/main::sqlite-3.41.1-h80987f9_0
#   terminado          conda-forge::terminado-0.15.0-py39h28~ --> pkgs/main::terminado-0.17.1-py39hca03da5_0
#   tornado            conda-forge::tornado-6.1-py39hb18efdd~ --> pkgs/main::tornado-6.2-py39h1a28f6b_0
#   tqdm               conda-forge/noarch::tqdm-4.63.0-pyhd8~ --> pkgs/main/osx-arm64::tqdm-4.65.0-py39h86d0a89_0
#   traitlets          conda-forge/noarch::traitlets-5.2.1.p~ --> pkgs/main/osx-arm64::traitlets-5.7.1-py39hca03da5_0
#   tzdata               conda-forge::tzdata-2022a-h191b570_0 --> pkgs/main::tzdata-2022g-h04d1e81_0
#   wheel              conda-forge/noarch::wheel-0.37.1-pyhd~ --> pkgs/main/osx-arm64::wheel-0.38.4-py39hca03da5_0
#   xz                       conda-forge::xz-5.2.5-h642e427_1 --> pkgs/main::xz-5.2.10-h80987f9_1
#   zipp               conda-forge/noarch::zipp-3.8.0-pyhd8e~ --> pkgs/main/osx-arm64::zipp-3.11.0-py39hca03da5_0
#   zlib               conda-forge::zlib-1.2.11-hee7b306_1013 --> pkgs/main::zlib-1.2.13-h5a0b063_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   appnope            conda-forge/noarch::appnope-0.1.3-pyh~ --> pkgs/main/osx-arm64::appnope-0.1.2-py39hca03da5_1001
#   argon2-cffi        conda-forge::argon2-cffi-21.3.0-pyhd8~ --> pkgs/main::argon2-cffi-21.3.0-pyhd3eb1b0_0
#   argon2-cffi-bindi~ conda-forge::argon2-cffi-bindings-21.~ --> pkgs/main::argon2-cffi-bindings-21.2.0-py39h1a28f6b_0
#   asttokens          conda-forge::asttokens-2.0.5-pyhd8ed1~ --> pkgs/main::asttokens-2.0.5-pyhd3eb1b0_0
#   backcall           conda-forge::backcall-0.2.0-pyh9f0ad1~ --> pkgs/main::backcall-0.2.0-pyhd3eb1b0_0
#   beautifulsoup4     conda-forge/noarch::beautifulsoup4-4.~ --> pkgs/main/osx-arm64::beautifulsoup4-4.11.1-py39hca03da5_0
#   bleach             conda-forge::bleach-5.0.0-pyhd8ed1ab_0 --> pkgs/main::bleach-4.1.0-pyhd3eb1b0_0
#   brotlipy           conda-forge::brotlipy-0.7.0-py39h5161~ --> pkgs/main::brotlipy-0.7.0-py39h1a28f6b_1002
#   charset-normalizer conda-forge::charset-normalizer-2.0.1~ --> pkgs/main::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   debugpy            conda-forge::debugpy-1.6.0-py39h0ef5a~ --> pkgs/main::debugpy-1.5.1-py39hc377ac9_0
#   decorator          conda-forge::decorator-5.1.1-pyhd8ed1~ --> pkgs/main::decorator-5.1.1-pyhd3eb1b0_0
#   defusedxml         conda-forge::defusedxml-0.7.1-pyhd8ed~ --> pkgs/main::defusedxml-0.7.1-pyhd3eb1b0_0
#   entrypoints        conda-forge/noarch::entrypoints-0.4-p~ --> pkgs/main/osx-arm64::entrypoints-0.4-py39hca03da5_0
#   executing          conda-forge::executing-0.8.3-pyhd8ed1~ --> pkgs/main::executing-0.8.3-pyhd3eb1b0_0
#   grpcio             conda-forge::grpcio-1.46.3-py39h518ba~ --> pkgs/main::grpcio-1.42.0-py39h95c9599_0
#   hdf5               conda-forge::hdf5-1.12.1-nompi_hf9525~ --> pkgs/main::hdf5-1.12.1-h160e8cb_2
#   ipython_genutils   conda-forge::ipython_genutils-0.2.0-p~ --> pkgs/main::ipython_genutils-0.2.0-pyhd3eb1b0_1
#   jedi               conda-forge::jedi-0.18.1-py39h2804cbe~ --> pkgs/main::jedi-0.18.1-py39hca03da5_1
#   jupyterlab_pygmen~ conda-forge::jupyterlab_pygments-0.2.~ --> pkgs/main::jupyterlab_pygments-0.1.2-py_0
#   jupyterlab_widgets conda-forge::jupyterlab_widgets-1.1.0~ --> pkgs/main::jupyterlab_widgets-1.0.0-pyhd3eb1b0_1
#   libev                  conda-forge::libev-4.33-h642e427_1 --> pkgs/main::libev-4.33-h1a28f6b_1
#   libnghttp2         conda-forge::libnghttp2-1.47.0-he723f~ --> pkgs/main::libnghttp2-1.46.0-h95c9599_0
#   libsodium          conda-forge::libsodium-1.0.18-h27ca64~ --> pkgs/main::libsodium-1.0.18-h1a28f6b_0
#   libssh2            conda-forge::libssh2-1.10.0-hb80f160_2 --> pkgs/main::libssh2-1.10.0-hf27765b_0
#   mistune            conda-forge::mistune-0.8.4-py39h51615~ --> pkgs/main::mistune-0.8.4-py39h1a28f6b_1000
#   nb_conda_kernels   conda-forge::nb_conda_kernels-2.3.1-p~ --> pkgs/main::nb_conda_kernels-2.3.1-py39hca03da5_0
#   nbclient           conda-forge/noarch::nbclient-0.5.13-p~ --> pkgs/main/osx-arm64::nbclient-0.5.13-py39hca03da5_0
#   pandocfilters      conda-forge::pandocfilters-1.5.0-pyhd~ --> pkgs/main::pandocfilters-1.5.0-pyhd3eb1b0_0
#   parso               conda-forge::parso-0.8.3-pyhd8ed1ab_0 --> pkgs/main::parso-0.8.3-pyhd3eb1b0_0
#   pickleshare        conda-forge::pickleshare-0.7.5-py_1003 --> pkgs/main::pickleshare-0.7.5-pyhd3eb1b0_1003
#   prometheus_client  conda-forge/noarch::prometheus_client~ --> pkgs/main/osx-arm64::prometheus_client-0.14.1-py39hca03da5_0
#   psutil             conda-forge::psutil-5.9.0-py39hb18efd~ --> pkgs/main::psutil-5.9.0-py39h1a28f6b_0
#   pure_eval          conda-forge::pure_eval-0.2.2-pyhd8ed1~ --> pkgs/main::pure_eval-0.2.2-pyhd3eb1b0_0
#   pycparser          conda-forge::pycparser-2.21-pyhd8ed1a~ --> pkgs/main::pycparser-2.21-pyhd3eb1b0_0
#   pygments           conda-forge::pygments-2.12.0-pyhd8ed1~ --> pkgs/main::pygments-2.11.2-pyhd3eb1b0_0
#   pyrsistent         conda-forge::pyrsistent-0.18.1-py39hb~ --> pkgs/main::pyrsistent-0.18.0-py39h1a28f6b_0
#   pysocks            conda-forge::pysocks-1.7.1-py39h2804c~ --> pkgs/main::pysocks-1.7.1-py39hca03da5_0
#   python-dateutil    conda-forge::python-dateutil-2.8.2-py~ --> pkgs/main::python-dateutil-2.8.2-pyhd3eb1b0_0
#   sniffio            conda-forge::sniffio-1.2.0-py39h2804c~ --> pkgs/main::sniffio-1.2.0-py39hca03da5_1
#   stack_data         conda-forge::stack_data-0.2.0-pyhd8ed~ --> pkgs/main::stack_data-0.2.0-pyhd3eb1b0_0
#   testpath           conda-forge/noarch::testpath-0.6.0-py~ --> pkgs/main/osx-arm64::testpath-0.6.0-py39hca03da5_0
#   tk                      conda-forge::tk-8.6.12-he1e0b03_0 --> pkgs/main::tk-8.6.12-hb8d0fd4_0
#   wcwidth            conda-forge::wcwidth-0.2.5-pyh9f0ad1d~ --> pkgs/main::wcwidth-0.2.5-pyhd3eb1b0_0
#   webencodings       conda-forge/noarch::webencodings-0.5.~ --> pkgs/main/osx-arm64::webencodings-0.5.1-py39hca03da5_1
#   websocket-client   conda-forge/noarch::websocket-client-~ --> pkgs/main/osx-arm64::websocket-client-0.58.0-py39hca03da5_4
#   zeromq               conda-forge::zeromq-4.3.4-hbdafb3b_1 --> pkgs/main::zeromq-4.3.4-hc377ac9_0
#
#
# Proceed ([y]/n)?

# %%
y
