# %%
i,k=0,0
while i<9:
    if i<5:
        k=0
        while k<4-i:
            print(' ',end=' ')
            k+=1
        k=0
        while k<i*2+1:
            print('\u2605',end=' ')
            k+=1
    else:
        k=0
        while k<i-4:
            print(' ',end=' ')
            k+=1
        k=0
        while k<(9-i)*2-1:
            print('\u2605',end=' ')
            k+=1
    print()
    i+=1
# Out:
#         ★
#       ★ ★ ★
#     ★ ★ ★ ★ ★
#   ★ ★ ★ ★ ★ ★ ★
# ★ ★ ★ ★ ★ ★ ★ ★ ★
#   ★ ★ ★ ★ ★ ★ ★
#     ★ ★ ★ ★ ★
#       ★ ★ ★
#         ★

# %%
for i in range(1, 6):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(5, 0, -1):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(1, 6):
    for k in range(5-i):
        print(" ", end="")
    for j in range(i):
        print("*", end="")
    print()
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
for i in range(1, 6):
    for k in range(5-i):
        print(" ", end="")
    for j in range(2*i-1):
        print("*", end="")
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
for i in range(1, 5):
    for k in range(5-i):
        print(" ", end="")
    for j in range(2*i-1):
        print("*", end="")
    print()
for i in range(5, 0, -1):
    for k in range(5-i):
        print(" ", end="")
    for j in range(2*i-1):
        print("*", end="")
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %%
for i in range(5, 1, -1):
    for k in range(5-i):
        print(" ", end="")
    for j in range(2*i-1):
        print("*", end="")
    print()
for i in range(1, 6):
    for k in range(5-i):
        print(" ", end="")
    for j in range(2*i-1):
        print("*", end="")
    print()
# Out:
# *********
#  *******
#   *****
#    ***
#     *
#    ***
#   *****
#  *******
# *********

# %%
for i in range(1, 6):
    for n in range(0, -i+5):
        print(" ", end='')
    for j in range(1, i*2, 1):
        print("*", end='')
    print()
for i in range(1,5):
    for n in range(0,i):
        print(" ", end="")
    for j in range(7, 2*i-2 ,-1):
        print("*", end='')
    print
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %%
for i in range(1, 5):
    for k in range(5-i):
        print(" ", end="")
    for j in range(2*i-1):
        print("*", end="")
    print()
for i in range(5, 0, -1):
    for k in range(5-i):
        print(" ", end="")
    for j in range(2*i-1):
        print("*", end="")
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %%
for i in range(1, 6):
    for n in range(7):
        print(" ", end='')
    for j in range(2*i-1):
        print("*", end="")
    print()
for i in range(6, 0, -1):
    for n in range(0, -2*i+12):
        print(" ", end='')
    for j in range(2*i-5):
        print("*", end="")
    print()
# Out:
#        *
#        ***
#        *****
#        *******
#        *********
# *******
#   *****
#     ***
#       *

# %%
for i in range(1,6):
    print(" "*7, end='')
    print("*"*(2*i-1))
for i in range(5, 0, -1):
    print(('*'*(2*i-3)).rjust(7))
# Out:
#        *
#        ***
#        *****
#        *******
#        *********
# *******
#   *****
#     ***
#       *

# %%
a = [1,3,5,7,9]
b = [7, 5, 3, 1]
c = [0, 2, 4, 6]

for i in a:
    for k in range(7):
        print(" ", end="")
    for j in range(i):
        print("*", end="")
    print()
    
for i in b:
    
    for j in range(i):
        print("*", end="")
    print()
# Out:
#        *
#        ***
#        *****
#        *******
#        *********
#     *******
#     *****
#     ***
#     *

# %%
for i in range(10):
    if i%2==0:
        continue
    if i==5:
        break
    print(i)
# Out:
# 1
# 3

# %%
with open("/Users/syshin/Desktop/Syshin/Study/Dacon/코스포 x 데이콘 자동차 충돌 분석 AI경진대회/test.csv", "r") as f:
    lines = f.readlines()
    csv_file = [line.rstrip().split(",") for line in lines]

# %%
csv_file
# Out:
# [['sample_id', 'video_path'],
#  ['TEST_0000', './test/TEST_0000.mp4'],
#  ['TEST_0001', './test/TEST_0001.mp4'],
#  ['TEST_0002', './test/TEST_0002.mp4'],
#  ['TEST_0003', './test/TEST_0003.mp4'],
#  ['TEST_0004', './test/TEST_0004.mp4'],
#  ['TEST_0005', './test/TEST_0005.mp4'],
#  ['TEST_0006', './test/TEST_0006.mp4'],
#  ['TEST_0007', './test/TEST_0007.mp4'],
#  ['TEST_0008', './test/TEST_0008.mp4'],
#  ['TEST_0009', './test/TEST_0009.mp4'],
#  ['TEST_0010', './test/TEST_0010.mp4'],
#  ['TEST_0011', './test/TEST_0011.mp4'],
#  ['TEST_0012', './test/TEST_0012.mp4'],
#  ['TEST_0013', './test/TEST_0013.mp4'],
#  ['TEST_0014', './test/TEST_0014.mp4'],
#  ['TEST_0015', './test/TEST_0015.mp4'],
#  ['TEST_0016', './test/TEST_0016.mp4'],
#  ['TEST_0017', './test/TEST_0017.mp4'],
#  ['TEST_0018', './test/TEST_0018.mp4'],
#  ['TEST_0019', './test/TEST_0019.mp4'],
#  ['TEST_0020', './test/TEST_0020.mp4'],
#  ['TEST_0021', './test/TEST_0021.mp4'],
#  ['TEST_0022', './test/TEST_0022.mp4'],
# ...
