# %%
import tkinter
from tkinter import *
from tkinter.messagebox import *
from tkinter.font import *

root = Tk()
root.title('AAA')
root.geometry('600x600+200+200')


 
frame1 = Frame(root)
frame1.grid(row=0, column=0, sticky="nsew")

frame2 = Frame(root)
frame2.grid(row=0, column=0, sticky="nsew")

frame3 = LabelFrame(root)
frame3.grid(row=0, column=0, sticky="nsew")

def loginCheck():
    if userId.get() == 'skku':
        if userPwd.get() == '1234':
            showinfo('성공','성공')
            openFrame(frame2)
        else:
            showinfo('fail','비밀번호 오류')
    else:
        showinfo('fail','로그인 실패')

Label(frame1, text='로그인 해주세요').grid(row=0, column=1, columnspan=2)
Label(frame1, text='아이디').grid(row=2)
Label(frame1, text='패스워드').grid(row=3)
Label(frame1, text='주소').grid(row=4)

userId = Entry(frame1)
userPwd = Entry(frame1, show='*')
userAdr = Entry(frame1)


btn1 = Button(frame1, text='확인', command=loginCheck, fg='green')
btn2 = Button(frame1, text='종료', command = quit)

userId.grid(row=2, column=1)
userPwd.grid(row=3, column=1)
userAdr.grid(row=4, column=1)
btn1.grid(row=5, column=1)
btn2.grid(row=6, column=1)


def openFrame(frame):
    frame.tkraise()

# %%
Userlist = []
def cb_click():
    if CheckVar1.get() == 1:
        print('난류 체크')
        Userlist.append('알')
    if CheckVar2.get() == 1:
        print('우유 체크')
        Userlist.append('우유')
    if CheckVar3.get() == 1:
        print('메밀 체크')
        Userlist.append('메밀')
    if CheckVar4.get() == 1:
        print('밀 체크')
        Userlist.append('밀')
    if CheckVar5.get() == 1:
        print('대두 체크')
        Userlist.append('대두')
    if CheckVar6.get() == 1:
        print('호두 체크')
        Userlist.append('호두')
    if CheckVar7.get() == 1:
        print('땅콩 체크')
        Userlist.append('땅콩')
    if CheckVar8.get() == 1:
        print('잣 체크')
        Userlist.append('잣')
    if CheckVar9.get() == 1:
        print('복숭아 체크')
        Userlist.append('복숭아')
    if CheckVar10.get() == 1:
        print('토마토 체크')
        Userlist.append('토마토')
    if CheckVar11.get() == 1:
        print('돼지고기 체크')
        Userlist.append('돼지고기')
    if CheckVar12.get() == 1:
        print('소고기 체크')
        Userlist.append('소고기')
    if CheckVar13.get() == 1:
        print('닭고기 체크')
        Userlist.append('닭고기')
    if CheckVar14.get() == 1:
        print('고등어 체크')
        Userlist.append('고등어')
    if CheckVar15.get() == 1:
        print('새우 체크')
        Userlist.append('새우')
    if CheckVar16.get() == 1:
        print('홍합 체크')
        Userlist.append('홍합')
    if CheckVar17.get() == 1:
        print('전복 체크')
        Userlist.append('전복')
    if CheckVar18.get() == 1:
        print('굴 체크')
        Userlist.append('굴')
    if CheckVar19.get() == 1:
        print('조개류 체크')
        Userlist.append('조개류')
    if CheckVar20.get() == 1:
        print('게 체크')
        Userlist.append('게')
    if CheckVar21.get() == 1:
        print('오징어 체크')
        Userlist.append('오징어')
    if CheckVar22.get() == 1:
        print('아황산류 체크')
        Userlist.append('아황산류')

    print(Userlist)

 
CheckVar1=IntVar()
CheckVar2=IntVar()
CheckVar3=IntVar()
CheckVar4=IntVar()
CheckVar5=IntVar()
CheckVar6=IntVar()
CheckVar7=IntVar()
CheckVar8=IntVar()
CheckVar9=IntVar()
CheckVar10=IntVar()
CheckVar11=IntVar()
CheckVar12=IntVar()
CheckVar13=IntVar()
CheckVar14=IntVar()
CheckVar15=IntVar()
CheckVar16=IntVar()
CheckVar17=IntVar()
CheckVar18=IntVar()
CheckVar19=IntVar()
CheckVar20=IntVar()
CheckVar21=IntVar()
CheckVar22=IntVar()

Label(frame2, text='이 식품 못먹어요').grid(row=0, column=1, columnspan=2)
c1=Checkbutton(frame2,text="난류",variable=CheckVar1)
c2=Checkbutton(frame2,text="우유",variable=CheckVar2)
c3=Checkbutton(frame2,text="메밀",variable=CheckVar3)
c4=Checkbutton(frame2,text="밀",variable=CheckVar4)
c5=Checkbutton(frame2,text="대두",variable=CheckVar5)
c6=Checkbutton(frame2,text="호두",variable=CheckVar6)
c7=Checkbutton(frame2,text="땅콩",variable=CheckVar7)
c8=Checkbutton(frame2,text="잣",variable=CheckVar8)
c9=Checkbutton(frame2,text="복숭아",variable=CheckVar9)
c10=Checkbutton(frame2,text="토마토",variable=CheckVar10)
c11=Checkbutton(frame2,text="돼지고기",variable=CheckVar11)
c12=Checkbutton(frame2,text="소고기",variable=CheckVar12)
c13=Checkbutton(frame2,text="닭고기",variable=CheckVar13)
c14=Checkbutton(frame2,text="고등어",variable=CheckVar14)
c15=Checkbutton(frame2,text="새우",variable=CheckVar15)
c16=Checkbutton(frame2,text="홍합",variable=CheckVar16)
c17=Checkbutton(frame2,text="전복",variable=CheckVar17)
c18=Checkbutton(frame2,text="굴",variable=CheckVar18)
c19=Checkbutton(frame2,text="조개류",variable=CheckVar19)
c20=Checkbutton(frame2,text="게",variable=CheckVar20)
c21=Checkbutton(frame2,text="오징어",variable=CheckVar21)
c22=Checkbutton(frame2,text="아황산류",variable=CheckVar22)

result_btn=tkinter.Button(frame2, text="체크완료",fg='green', command=cb_click)
result_btn.grid(column=0, row=7, columnspan=5)
c1.grid(column=0, row=1)
c2.grid(column=1, row=1)
c3.grid(column=2, row=1)
c4.grid(column=3, row=1)
c5.grid(column=0, row=2)
c6.grid(column=1, row=2)
c7.grid(column=2, row=2)
c8.grid(column=3, row=2)
c9.grid(column=0, row=3)
c10.grid(column=1, row=3)
c11.grid(column=2, row=3)
c12.grid(column=3, row=3)
c13.grid(column=0, row=4)
c14.grid(column=1, row=4)
c15.grid(column=2, row=4)
c16.grid(column=3, row=4)
c17.grid(column=0, row=5)
c18.grid(column=1, row=5)
c19.grid(column=2, row=5)
c20.grid(column=3, row=5)
c21.grid(column=0, row=6)
c22.grid(column=1, row=6)

# %%
openFrame(frame1)
root.mainloop()
